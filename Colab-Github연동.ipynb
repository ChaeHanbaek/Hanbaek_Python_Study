# %% [markdown]
# 최초 설정

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
cd /content/drive/MyDrive/Colab Notebooks
# Out:
# /content/drive/MyDrive/Colab Notebooks

# %%
# !git clone https://ChaeHanbaek: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@github.com/ChaeHanbaek/Hanbag_Python_Study.git
# Out:
# fatal: destination path 'Hanbag_Python_Study' already exists and is not an empty directory.

# %%
# !git config --global user.email 'cogksqor@gmail.com'
# !git config --global user.name 'ChaeHanbaek'

# %% [markdown]
# 이후 백업

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
cd /content/drive/MyDrive/Colab Notebooks/Hanbag_Python_Study
# Out:
# /content/drive/MyDrive/Colab Notebooks/Hanbag_Python_Study

# %%
#본인임을 확인
# !git config --global user.email 'cogksqor@gmail.com'
# !git config --global user.name 'ChaeHanbaek'
#폴더 add
# !git init
# !git add --all
# Out:
# Initialized empty Git repository in /content/drive/MyDrive/Colab Notebooks/Hanbag_Python_Study/.git/

# %%
#push
# !git commit -m 'Colab_Auto_Backup'
# !git push
# Out:
# On branch master
# Changes not staged for commit:
# 	modified:   "Colab-Github\341\204\213\341\205\247\341\206\253\341\204\203\341\205\251\341\206\274.ipynb"
#
# no changes added to commit
# fatal: The current branch master has no upstream branch.
# To push the current branch and set the remote as upstream, use
#
#     git push --set-upstream origin master

# %% [markdown]
# 토큰만료시 교체

# %%
# !git remote remove origin

# %%
# !git remote add origin https://ChaeHanbaek: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@github.com/ChaeHanbaek/Hanbag_Python_Study.git

# %%
# !git push -u origin master
# Out:
# error: src refspec master does not match any.
# error: failed to push some refs to 'https://ChaeHanbaek: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@github.com/ChaeHanbaek/Hanbag_Python_Study.git'

# %%
# !git init
# !git add .
# !git commit -m "init"
# !git remote add origin https://ChaeHanbaek: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@github.com/ChaeHanbaek/Hanbag_Python_Study.git
# !git push -u origin master
# Out:
# Reinitialized existing Git repository in /content/drive/MyDrive/Colab Notebooks/Hanbag_Python_Study/.git/
# On branch main
# nothing to commit, working tree clean
# error: src refspec master does not match any.
# error: failed to push some refs to 'https://ChaeHanbaek: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@github.com/ChaeHanbaek/Hanbag_Python_Study.git'
