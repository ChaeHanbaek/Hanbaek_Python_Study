# %% [markdown]
# 최초 설정

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/Colab Notebooks
# Out:
# /content/drive/MyDrive/Colab Notebooks

# %%
# !git clone https://ChaeHanbaek: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@github.com/ChaeHanbaek/Hanbag_Python_Study.git
# Out:
# Cloning into 'Hanbag_Python_Study'...
# remote: Enumerating objects: 95, done.
# remote: Counting objects: 100% (93/93), done.
# remote: Compressing objects: 100% (60/60), done.
# remote: Total 95 (delta 37), reused 83 (delta 33), pack-reused 2
# Unpacking objects: 100% (95/95), done.

# %%
# !git config --global user.email 'cogksqor@gmail.com'
# !git config --global user.name 'ChaeHanbaek'

# %% [markdown]
# 이후 백업

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/Colab Notebooks/Hanbag_Python_Study
# Out:
# /content/drive/MyDrive/Colab Notebooks/Hanbag_Python_Study

# %%
#본인임을 확인
# !git config --global user.email 'cogksqor@gmail.com'
# !git config --global user.name 'ChaeHanbaek'
#폴더 add
# !git add --all

# %%
#push
# !git commit -m 'Colab_Auto_Backup'
# !git push
# Out:
# [main d85ec7b] Colab_Auto_Backup
#  26 files changed, 26 insertions(+)
#  create mode 100644 "0404 \341\204\211\341\205\265\341\206\257\341\204\211\341\205\263\341\206\270.ipynb"
#  create mode 100644 "0516 Set \341\204\217\341\205\263\341\206\257\341\204\205\341\205\242\341\204\211\341\205\263\341\204\206\341\205\241\341\206\253\341\204\203\341\205\263\341\206\257\341\204\200\341\205\265.ipynb"
#  create mode 100644 "0516 \341\204\200\341\205\252\341\206\257\341\204\222\341\205\251\341\204\200\341\205\245\341\206\267\341\204\211\341\205\241\341\204\200\341\205\265(\341\204\211\341\205\263\341\204\220\341\205\242\341\206\250 \341\204\213\341\205\263\341\206\274\341\204\213\341\205\255\341\206\274).ipynb"
# ...
