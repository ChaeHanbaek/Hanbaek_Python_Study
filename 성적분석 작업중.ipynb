# %%
import random
import csv
import copy
import pandas as pd
import matplotlib.pyplot as plt

# %%
class data_analysis:
    #클래스 속성, 상속받는 개체들도 이를 공유
    default_rand_nums = 10
    default_min_of_rand_num = 0
    default_max_of_rand_num = 10

    def __init__(self, _num_class = 1):
      # 인스턴스 속성, 인스턴스화 할때마다 다르게 얻음
        self.num_class = _num_class #학년마다 클래스 다르게 갖고 싶음
        self.default_rand_nums = data_analysis.default_rand_nums
        self.default_min_of_rand_num = data_analysis.default_min_of_rand_num
        self.default_max_of_rand_num = data_analysis.default_max_of_rand_num

        self.str_inform = ("""이 프로그램은 임의의 숫자를 생성하고, 그 결과를  csv 파일로 저장, 통계 분석하는 기능을 제공합니다.\
        \n숫자를 생성하기 위하여, 생성할 숫자의 갯수(n), 임의의 숫자 생성을 위한 범위의 최솟값(min), 최댓값(max)를 설정 할 수 있습니다.\
        \n이 설정 옵션의 기본값은  n = {n}, min = {min}, max = {max}입니다.\n
        """.format(n = self.default_rand_nums, min = self.default_min_of_rand_num, max = self.default_max_of_rand_num))

        self.str_rand_num = "생성할 숫자의 옵션 n, min, max를 스페이스바로 구분하여 순서대로 입력해 주세요('q', 'd' 입력 가능) : "
        self.file_name = ""
        self.raw_datas = []
        self.select_datas = []
        #클래스는 캡슐화가 목적이라 함수에서 반환안해도 됨, 밑에 get_raw_datas(self), get_res_datas(self)같이 간접적으로 표시해줄수 있으면 됨
        self.var = 0
        self.std = 0
        self.cdf = []
        self.prob = []

    def program_infom(self):
        print(self.str_inform)

    def init_datas(self):
        self.raw_datas = []
        self.select_datas = []
        self.mean = 0
        self.var = 0
        self.std = 0
        self.cdf = []
        self.prob = []

    def get_raw_datas(self):
        return self.raw_datas

    def get_res_datas(self):
        return [self.select_datas, self.mean, self.var, self.std, self.cdf, self.prob]
    
    def gen_rand_num(self, _nums = None, _min = None, _max = None):
        if _nums == None:
            _nums = self.default_rand_nums
        if _min == None:
            _min = self.default_min_of_rand_num
        if _max == None:
            _max = self.default_max_of_rand_num

        res = []
        for i in range(_nums):
            num = random.randint(_min, _max)        
            res.append(num)
        self.raw_datas.append(res)

    def save_csv(self, _data = None, _tag = True):
        self.file_name = input("csv 파일명을 입력해 주세요 : ");
        with open("{}.csv".format(self.file_name), mode = 'w', encoding = 'utf-8-sig') as f:
            try:
                w = csv.writer(f)

                if _data != None:
                    if _tag:
                        max_len = 0
                        for i in _data:
                            if len(i) > max_len:
                                max_len = len(i)
                        
                        tags = []
                        index = 0
                        for i in range(max_len):
                            tags.append("data{}".format(index))
                            index += 1
                        w.writerow(tags)

                    for i in _data:
                        w.writerow(i)
                    print("{}.csv 파일 저장에 성공하였습니다.".format(self.file_name))
                    return True, self.file_name
                else:
                    if _tag:
                        max_len = 0
                        for i in self.raw_datas:
                            if len(i) > max_len:
                                max_len = len(i)
                        
                        tags = []
                        index = 0
                        for i in range(max_len):
                            tags.append("data{}".format(index))
                            index += 1
                        w.writerow(tags)

                    for i in self.raw_datas:
                        w.writerow(i)
                    print("{}.csv 파일 저장에 성공하였습니다.".format(self.file_name))
                    return True, self.file_name

            except:
                print("csv 파일 저장에 실패하였습니다.")
                return False, None
        
    def read_csv(self, _new = False):
        if _new:
            while True:
                try:
                    self.file_name = input("csv 파일명을 입력해 주세요 : ");
                    with open("{}.csv".format(self.file_name), mode = 'r', encoding = 'utf-8-sig') as f:        
                        r = csv.reader(f)
                        self.raw_datas = []                        
                        for data in r:
                            self.raw_datas.append(data)
                        
                        print("csv 파일 불러오기에 성공하였습니다.")                        
                except:
                    print("{}.csv 파일이 존재하지 않습니다".format(self.file_name))
        else:
            try:                
                with open("{}.csv".format(self.file_name), mode = 'r', encoding = 'utf-8-sig') as f:        
                    r = csv.reader(f)
                    self.raw_datas = []
                    for data in r:
                        self.raw_datas.append(data)
                    
                    print("csv 파일 불러오기에 성공하였습니다.")                    
            except:
                print("{}.csv 파일이 존재하지 않습니다".format(self.file_name))

    def get_target_datas(self, _mode = 'r', _loc = [0]):
        if _mode == 'r': 
            if abs(_loc[0]) > abs(len(self.raw_datas)):
                print("데이터의 범위를 초과합니다.\n")
                return
            self.select_datas = self.raw_datas[_loc[0]]
        elif _mode == 'c':
            res = []
            for data in self.raw_datas:
                if abs(len(data)) > abs(_loc[0]):
                    res.append(data[_loc[0]])
            
            if len(res) == 0:
                print("데이터의 범위를 초과합니다.\n")
                return

            self.select_datas = res
        elif _mode == 'p':
            if abs(_loc[0]) < abs(len(self.raw_datas)):
                if abs(_loc[1]) < abs(len(self.raw_datas[_loc[0]])):
                    self.select_datas = self.raw_datas[_loc[0]][_loc[1]]
            
            print("데이터의 범위를 초과합니다.")

    def calc_mean(self):
        int_data = list(map(int, self.select_datas))
        if len(int_data) > 0:
            self.mean = sum(int_data)/len(int_data)
        else:
            print("데이터가 존재하지 않습니다")

    def calc_var_std(self):
        int_data = list(map(int, self.select_datas))
        if len(int_data) > 0:
            var = 0
            for data in int_data:
                var += (data - self.mean)**2
            var /= len(int_data)

            self.var = var
            self.std = var**0.5            
        else:
            print("데이터가 존재하지 않습니다")

    def calc_cdf_prob(self):
        int_data = list(map(int, self.select_datas))
        if len(int_data) > 0:
            elems = set(int_data)
            sort_elems = sorted(elems)
            self.cdf = []
            cdf_index = {}
            index = 0
            for elem in sort_elems:
                self.cdf.append([elem, 0])
                cdf_index.update({str(elem): index})
                index += 1
            
            for data in int_data:
                loc = cdf_index[str(data)]
                self.cdf[loc][1] += 1
            
            len_data = len(int_data)
            self.prob = [[data[0], data[1]/len_data*100] for data in self.cdf]
        else:
            print("데이터가 존재하지 않습니다")

# %% [markdown]
# 성적계산기로 개조해서 완성
# 성적 랜덤하게 입력, a,b,c,d 학점 입력(과목별), 등수별로 정렬(통합), matplotlib활용
# 한학년 만든다음, 과목수 몇반, 반별 학생수 정보 가정
# 과목수 국영수과 4과목
# 반평균 반석차 학년평균 학년석차 과목별 평균 분산
# 다음주 월요일까지 만들어보기
# 학생데이터 [번호,{"국어":점수,"영어":점수,"수학":점수,"과학":점수}]

# %%
class score():
  #score(학년,반수)로 새 클래스 작성
  def __init__(self,학년,반수):
    self.str_grade="{}학년".format(학년)
    self.grade = [self.str_grade]
    for i in range(1,반수+1): #0부터 시작하는거 보정
      x="{}학년 {}반".format(학년,i)
      self.grade.append([x])
    self.A=90
    self.B=80
    self.C=70
    self.results=[]
  
  def 학년성적입력(self,학년성적목록):
    try:
      self.grade=학년성적목록
    except ValueError:
      print("지정된 형태의 데이터가 아닙니다.")

  #성적 입력/수정함수
  #성적목록은 ["i학년 j반", ["1번",{"국어":70,"수학":60,"영어":80,"과학":40}], ...., ["k번",{"국어":50,"수학":30,"영어":60,"과학":50}]] 꼴로 가정
  #수정 성적 목록은 ["i학년 j반", [{"학생정보":i학년j반k번","국어":70,"수학":60,"영어":80,"과학":40}], ...., [{"학생정보":i학년j반k번","국어":50,"수학":30,"영어":60,"과학":50}]]로 가정
  def 반별성적입력(self,반번호,반성적목록):
    try:
      self.grade[반번호]=반성적목록
    except ValueError:
      print("지정된 형태의 데이터가 아닙니다.")


  #성적은 {"국어":70,"수학":60,"영어":80,"과학":40}꼴로 가정
  def 학생별성적입력(self,반번호,학생번호,성적):
    try:
      sl={"학생":"{}{}반{}번".format(self.str_grade,반번호,학생번호)}
      sl.update(성적)
      self.grade[반번호].insert(학생번호,sl)
    except ValueError:
      print("지정된 형태의 데이터가 아닙니다.")

  def csv저장(self):
    try:
      f = open("{}.csv".format(self.grade[0]), mode = 'w', encoding = 'utf-8-sig')
      w = csv.writer(f)
      t= self.grade
      #학년에서 가장 학생이 많은 반을 찾아서 그거 기준으로 태그 입력
      max_student=0
      for j in range(1,len(t)):
        if len(t[j]) > max_student:
          max_student=len(t[j])
      tags=["구분"]
      for n in range(1,max_student):
        tags.append("{}번".format(n))
      print(tags) #tag정상 생성 확인용
      w.writerow(tags)
      for j in range(1,len(t)):
        w.writerow(t[j])
      print("{}.csv파일에 저장하였습니다.".format(self.grade[0]))
    except:
      print("{}.csv파일에 저장하지 못했습니다.".format(self.grade[0]))


  def csv열기(self,fn): #문제점 발견, 학생의 자료를 저장하고 불러올때 [str,{}]꼴이 유지된게 아니라 통째 str로 인식 ->해동함수로 해결
    try:
      slist=[]
      f=open("{}.csv".format(fn),mode='r',encoding='utf-8-sig')
      w=csv.reader(f)
      slist.extend(w)
      slist[0]=fn
      self.grade=slist
      for j in range(1,len(self.grade)): #j반
        t=self.grade[j]
        for k in range(1,len(t)): #k번
          t[k]=self.해동(t[k])
      print(self.grade)
      print("{}.csv파일을 여는데 성공했습니다.".format(fn))
    except:
      print("{}.csv파일을 여는데 실패했습니다.".format(fn))

  #{"학생정보":'6학년1반1번','국어': 42, '영어': 34, '수학': 53, '과학': 87}모양의 string을 원래대로 리스트와 딕셔너리로 변환하는 새로운 함수 필요
  #위 역할을 하는 해동함수만들어 보완
  def 해동(self,학생데이터):
    temp_list=학생데이터.split(',')
    for i in range(len(temp_list)):
      temp_list[i]=temp_list[i].replace("{","").replace("}","").replace("'","").replace(" ","") #연속작업을 이렇게도 처리 가능
    D={}
    for X in temp_list:
      if ':' in X:
        T=X.split(':')
        #print(T) #정상작동 확인용
        D[T[0]]=T[1]
    D['국어']=int(D['국어'])
    D['영어']=int(D['영어'])
    D['수학']=int(D['수학'])
    D['과학']=int(D['과학'])
    return D

# %%
#데이터형 바꾸고 해동함수 개선
def 해동(학생데이터):
  temp_list=학생데이터.split(',')
  for i in range(len(temp_list)):
    temp_list[i]=temp_list[i].replace("{","").replace("}","").replace("'","").replace(" ","") #연속작업을 이렇게도 처리 가능
  D={}
  for X in temp_list:
    if ':' in X:
      T=X.split(':')
      #print(T) #정상작동 확인용
      D[T[0]]=T[1]
  D['국어']=int(D['국어'])
  D['영어']=int(D['영어'])
  D['수학']=int(D['수학'])
  D['과학']=int(D['과학'])
  return D

S="{'학생':'6학년1반1번','국어': 42, '영어': 34, '수학': 53, '과학': 87}"
D=해동(S)
print(D["학생"])
print(D["국어"])
print(D["국어"]+D["수학"])
# Out:
# 6학년1반1번
# 42
# 95

# %%
#1~6학년 각각 랜덤하게 클래스만들고 랜덤한 학생들에게 랜덤으로 성적 채워넣기
min_stu=5
max_stu=10
min_score=30
max_score=100
for i in range(1,7): #i 학년
  globals()["학년{}".format(i)]=score(i,random.randint(3,10))
  t=vars()["학년{}".format(i)]
  for j in range(1,len(t.grade)): #j 반
    for k in range(1,random.randint(min_stu,max_stu)): #k번
      st_score={"국어":random.randint(min_score,max_score),"영어":random.randint(min_score,max_score),"수학":random.randint(min_score,max_score),"과학":random.randint(min_score,max_score)}
      t.학생별성적입력(j,k,st_score)
  print(t.grade) #작동 확인용

#각 학년별로 csv파일 따로 만들어서 저장
for i in range(1,7):
  t=vars()["학년{}".format(i)]
  print(t.grade)
  t.csv저장()
total=["학교",학년1.grade,학년2.grade,학년3.grade,학년4.grade,학년5.grade,학년6.grade]
print(total) #total[학년][반][번호]로 어떤 학생이든 접근 가능 total[학년][반][번호][1]["수학"]
print(total[2][3][1]) #학생 번호
print(total[2][3][1]["수학"]) #학생성적
# Out:
# ['1학년', ['1학년 1반', {'학생': '1학년1반1번', '국어': 59, '영어': 92, '수학': 51, '과학': 40}, {'학생': '1학년1반2번', '국어': 37, '영어': 30, '수학': 68, '과학': 73}, {'학생': '1학년1반3번', '국어': 90, '영어': 94, '수학': 64, '과학': 56}, {'학생': '1학년1반4번', '국어': 38, '영어': 57, '수학': 56, '과학': 79}, {'학생': '1학년1반5번', '국어': 60, '영어': 81, '수학': 67, '과학': 62}, {'학생': '1학년1반6번', '국어': 45, '영어': 37, '수학': 67, '과학': 63}, {'학생': '1학년1반7번', '국어': 95, '영어': 94, '수학': 100, '과학': 55}], ['1학년 2반', {'학생': '1학년2반1번', '국어': 47, '영어': 63, '수학': 64, '과학': 55}, {'학생': '1학년2반2번', '국어': 59, '영어': 94, '수학': 67, '과학': 88}, {'학생': '1학년2반3번', '국어': 32, '영어': 82, '수학': 48, '과학': 46}, {'학생': '1학년2반4번', '국어': 99, '영어': 62, '수학': 55, '과학': 66}], ['1학년 3반', {'학생': '1학년3반1번', '국어': 55, '영어': 74, '수학': 96, '과학': 31}, {'학생': '1학년3반2번', '국어': 68, '영어': 52, '수학': 90, '과학': 71}, {'학생': '1학년3반3번', '국어': 98, '영어': 86, '수학': 84, '과학': 69}, {'학생': '1학년3반4번', '국어': 86, '영어': 86, '수학': 62, '과학': 35}, {'학생': '1학년3반5번', '국어': 37, '영어': 62, '수학': 55, '과학': 76}]]
학': 63, '과학': 36}, {'학생': '2학년6반3번', '국어': 78, '영어': 79, '수학': 84, '과학': 85}, {'학생': '2학년6반4번', '국어': 77, '영어': 94, '수학': 75, '과학': 40}, {'학생': '2학년6반5번', '국어': 99, '영어': 66, '수학': 100, '과학': 36}, {'학생': '2학년6반6번', '국어': 63, '영어': 34, '수학': 81, '과학': 88}, {'학생': '2학년6반7번', '국어': 48, '영어': 77, '수학': 53, '과학': 76}], ['2학년 7반', {'학생': '2학년7반1번', '국어': 82, '영어': 58, '수학': 44, '과학': 79}, {'학생': '2학년7반2번', '국어': 89, '영어': 81, '수학': 60, '과학': 40}, {'학생': '2학년7반3번', '국어': 32, '영어': 39, '수학': 58, '과학': 95}, {'학생': '2학년7반4번', '국어': 80, '영어': 100, '수학': 35, '과학': 67}, {'학생': '2학년7반5번', '국어': 50, '영어': 92, '수학': 60, '과학': 38}, {'학생': '2학년7반6번', '국어': 41, '영어': 87, '수학': 98, '과학': 77}], ['2학년 8반', {'학생': '2학년8반1번', '국어': 97, '영어': 31, '수학': 58, '과학': 46}, {'학생': '2학년8반2번', '국어': 47, '영어': 32, '수학': 66, '과학': 56}, {' ...
# {'학생': '2학년3반1번', '국어': 54, '영어': 54, '수학': 79, '과학': 53}
# 79

# %%
class score_analysis(score):
  def __init__(self):
    #self.grade=[] #학년별 성적이 들어있는 데이터, score를 상속받아서 따로 선언해줄필요 없음
    self.results=[]
    #점수 기준 설정
    self.A=90
    self.B=80
    self.C=70
    #self.D=60 D기준은 없어도 될듯, A기준이상 A, B기준 이상 B, C기준 이상 C, 그 미만 D

  #csv열기 메소드 오버라이딩이 이상하게 안됨 그래서 아래 함수 따로 만들어서 실행시켜줘야 results리스트가 제대로 생성됨
  def 성적처리시작(self):
    self.results=copy.deepcopy(self.grade)
    self.results[0]={"학년":self.results[0]}
    for j in range(1,len(self.results)):
     self.results[j][0]={"반":self.results[j][0]}
    print("성적처리 준비가 완료되었습니다.")

  #하나로 합칠수 있을거 같긴한데 아래보다 길어질거 같음
  def A기준바꾸기(self,n):
    self.A=n
  def B기준바꾸기(self,n):
    self.B=n
  def C기준바꾸기(self,n):
    self.C=n

  def 등급판정(self,점수):
    if 점수 >= self.A:
      return 'A'
    elif 점수 >= self.B:
      return 'B'
    elif 점수 >= self.C:
      return 'C'
    elif 점수 < self.C:
      return 'D'
    else:
      print("잘못된 값입니다.")
      return 'err'

  def 등급부여(self):
    for j in range(1,len(self.grade)):
      t=self.grade[j] #j반
      for k in range(1,len(t)):
        tt=t[k]    
        self.results[j][k].update({"국어":self.등급판정(int(tt["국어"])),"영어":self.등급판정(int(tt["영어"])),"수학":self.등급판정(int(tt["수학"])),"과학":self.등급판정(int(tt["과학"]))})
        
  def 학생평균계산(self):
      for j in range(1,len(self.grade)):
        t=self.grade[j] #j반
        for k in range(1,len(t)):
          tt=t[k]
          total=int(tt["국어"])+int(tt["영어"])+int(tt["수학"])+int(tt["과학"])
          mean=total/4
          self.results[j][k]["평균"]=mean
      return mean

  def 반평균계산(self,반번호):
      반평균=0
      t=self.results[반번호]
      for k in range(1,len(t)):
        반평균 += t[k]["평균"]
      반평균 = 반평균/(len(t)-1) #인덱스 0은 숫자에서 제외
      self.results[반번호][0]["반평균"]=반평균
      return 반평균

  def 학년평균계산(self):
    학년평균=0
    for j in range(1,len(self.results)):
      self.반평균계산(j)
      학년평균 += self.results[j][0]["반평균"]
    학년평균 = 학년평균 / (len(self.results)-1)  #인덱스 0은 숫자에서 제외
    self.results[0]["학년평균"]=학년평균
    return 학년평균

  def 반분산표준편차계산(self,반번호):
    반분산=0
    t=self.results[반번호]
    if t[0]["반평균"]>0:
      반평균=t[0]["반평균"]
    else:
      반평균=self.반평균계산(반번호)
    for k in range(1,len(t)):
      반분산 += (t[k]["평균"]-반평균)**2
    반분산 = 반분산/(len(t)-1)
    반표준편차 = 반분산 ** 0.5
    t[0]["반분산"]=반분산
    t[0]["반표준편차"]=반표준편차
    return 반분산, 반표준편차

  def 학년분산표준편차계산(self):
    if self.results[0]["학년평균"]>0:
      학년평균=self.results[0]["학년평균"]
    else:
      반평균=self.학년평균계산()
    학년분산=0
    학생수=0
    for j in range(1,len(self.results)):
      t=self.results[j] #j반의 데이터
      학생수 += len(t)-1 #j반의 학생수를 더함
      for k in range(1,len(t)):
        학년분산 += (t[k]["평균"]-학년평균)**2
    학년분산= 학년분산 / 학생수
    학년표준편차 = 학년분산 ** 0.5
    self.results[0]["학년분산"]=학년분산
    self.results[0]["학년표준편차"]=학년표준편차
    return 학년분산, 학년표준편차

  def 과목별반누적분포빈도계산(self,과목명,반번호):
    과목d={}
    반빈도={}
    점수s=set()
    if 과목명 =="평균":
      t=self.results[반번호]
    else: 
      t=self.grade[반번호]
    for k in range(1,len(t)):
      점수s.add(t[k][과목명])
    점수s=list(점수s)
    td=dict.fromkeys(점수s,0)
    과목d.update(td)
    반빈도.update(td)
    #print(과목d) #작동 확인용
    for k in range(1,len(t)):
      _str=t[k][과목명]
      과목d[_str]=과목d[_str]+1
      반빈도[_str]=과목d[_str]+1
    self.results[반번호][0]["{}_반누적분포".format(과목명)]=과목d
    for x in td:
      반빈도[x]=반빈도[x]/(len(t)-1)
    self.results[반번호][0]["{}_반빈도".format(과목명)]=반빈도
    #print(self.results[반번호][0]) #작동 확인용
    return 과목d, 반빈도

  def 통합반누적분포빈도계산(self,반번호):
      과목=["국어","영어","수학","과학","평균"]
      for x in 과목:
        self.과목별반누적분포빈도계산(x,반번호)
      print("{}반의 누적분포와 빈도가 계산되었습니다.".format(반번호))

  def 학년과목별누적분포빈도계산(self,과목명):
    t=self.results
    키값=[]
    누적분포={}
    빈도={}
    학생수=0
    for j in range(1,len(t)):
      키값.extend((t[j][0]["{}_반누적분포".format(과목명)]).keys())
      학생수=학생수+(len(t[j])-1)
    키값=set(키값)
    키값=list(키값)
    임시d=dict.fromkeys(키값,0)
    for x in 키값:
      for j in range(1,len(t)):
        if type(t[j][0]["{}_반누적분포".format(과목명)].get(x))==int: #get을 사용해야 에러발생 피할수있음
          임시d[x] = 임시d[x]+1
    print(임시d)
    t[0]["{}_학년누적분포".format(과목명)]=임시d
    빈도=copy.deepcopy(임시d)
    for x in 키값:
      빈도[x]=빈도[x]/학생수
    print(빈도)
    t[0]["{}_학년빈도".format(과목명)]=빈도
    return 임시d, 빈도

  def 학년전체누적분포빈도계산(self):
    t=self.results
    for j in range(1,len(t)):
     self.통합반누적분포빈도계산(j)
    과목=["국어","영어","수학","과학","평균"]
    for x in 과목:
      self.학년과목별누적분포빈도계산(x)

# %%
학년x=score_analysis()
학년x.csv열기("1학년")
print(학년x.grade)
학년x.성적처리시작()
print(학년x.results)
print(학년x.등급판정(80))
학년x.등급부여()
print(학년x.results)
학년x.학생평균계산()
print(학년x.results)
학년x.반평균계산(1)
print(학년x.results)
학년x.학년평균계산()
print(학년x.results)
학년x.반분산표준편차계산(1)
print(학년x.results)
학년x.학년분산표준편차계산()
print(학년x.results)
학년x.통합반누적분포빈도계산(1)
학년x.학년전체누적분포빈도계산()
print(학년x.results)
# Out:
# ['1학년', ['1학년 1반', {'학생': '1학년1반1번', '국어': 59, '영어': 92, '수학': 51, '과학': 40}, {'학생': '1학년1반2번', '국어': 37, '영어': 30, '수학': 68, '과학': 73}, {'학생': '1학년1반3번', '국어': 90, '영어': 94, '수학': 64, '과학': 56}, {'학생': '1학년1반4번', '국어': 38, '영어': 57, '수학': 56, '과학': 79}, {'학생': '1학년1반5번', '국어': 60, '영어': 81, '수학': 67, '과학': 62}, {'학생': '1학년1반6번', '국어': 45, '영어': 37, '수학': 67, '과학': 63}, {'학생': '1학년1반7번', '국어': 95, '영어': 94, '수학': 100, '과학': 55}], ['1학년 2반', {'학생': '1학년2반1번', '국어': 47, '영어': 63, '수학': 64, '과학': 55}, {'학생': '1학년2반2번', '국어': 59, '영어': 94, '수학': 67, '과학': 88}, {'학생': '1학년2반3번', '국어': 32, '영어': 82, '수학': 48, '과학': 46}, {'학생': '1학년2반4번', '국어': 99, '영어': 62, '수학': 55, '과학': 66}], ['1학년 3반', {'학생': '1학년3반1번', '국어': 55, '영어': 74, '수학': 96, '과학': 31}, {'학생': '1학년3반2번', '국어': 68, '영어': 52, '수학': 90, '과학': 71}, {'학생': '1학년3반3번', '국어': 98, '영어': 86, '수학': 84, '과학': 69}, {'학생': '1학년3반4번', '국어': 86, '영어': 86, '수학': 62, '과학': 35}, {'학생': '1학년3반5번', '국어': 37, '영어': 62, '수학': 55, '과학': 76}]]
# 1학년.csv파일을 여는데 성공했습니다.
# ['1학년', ['1학년 1반', {'학생': '1학년1반1번', '국어': 59, '영어': 92, '수학': 51, '과학': 40}, {'학생': '1학년1반2번', '국어': 37, '영어': 30, '수학': 68, '과학': 73}, {'학생': '1학년1반3번', '국어': 90, '영어': 94, '수학': 64, '과학': 56}, {'학생': '1학년1반4번', '국어': 38, '영어': 57, '수학': 56, '과학': 79}, {'학생': '1학년1반5번', '국어': 60, '영어': 81, '수학': 67, '과학': 62}, {'학생': '1학년1반6번', '국어': 45, '영어': 37, '수학': 67, '과학': 63}, {'학생': '1학년1반7번', '국어': 95, '영어': 94, '수학': 100, '과학': 55}], ['1학년 2반', {'학생': '1학년2반1번', '국어': 47, '영어': 63, '수학': 64, '과학': 55}, {'학생': '1학년2반2번', '국어': 59, '영어': 94, '수학': 67, '과학': 88}, {'학생': '1학년2반3번', '국어': 32, '영어': 82, '수학': 48, '과학': 46}, {'학생': '1학년2반4번', '국어': 99, '영어': 62, '수학': 55, '과학': 66}], ['1학년 3반', {'학생': '1학년3반1번', '국어': 55, '영어': 74, '수학': 96, '과학': 31}, {'학생': '1학년3반2번', '국어': 68, '영어': 52, '수학': 90, '과학': 71}, {'학생': '1학년3반3번', '국어': 98, '영어': 86, '수학': 84, '과학': 69}, {'학생': '1학년3반4번', '국어': 86, '영어': 86, '수학': 62, '과학': 35}, {'학생': '1학년3반5번', '국어': 37, '영어': 62, '수학': 55, '과학': 76}]]
# 성적처리 준비가 완료되었습니다.
# [{'학년': '1학년'}, [{'반': '1학년 1반'}, {'학생': '1학년1반1번', '국어': 59, '영어': 92, '수학': 51, '과학': 40}, {'학생': '1학년1반2번', '국어': 37, '영어': 30, '수학': 68, '과학': 73}, {'학생': '1학년1반3번', '국어': 90, '영어': 94, '수학': 64, '과학': 56}, {'학생': '1학년1반4번', '국어': 38, '영어': 57, '수학': 56, '과학': 79}, {'학생': '1학년1반5번', '국어': 60, '영어': 81, '수학': 67, '과학': 62}, {'학생': '1학년1반6번', '국어': 45, '영어': 37, '수학': 67, '과학': 63}, {'학생': '1학년1반7번', '국어': 95, '영어': 94, '수학': 100, '과학': 55}], [{'반': '1학년 2반'}, {'학생': '1학년2반1번', '국어': 47, '영어': 63, '수학': 64, '과학': 55}, {'학생': '1학년2반2번', '국어': 59, '영어': 94, '수학': 67, '과학': 88}, {'학생': '1학년2반3번', '국어': 32, '영어': 82, '수학': 48, '과학': 46}, {'학생': '1학년2반4번', '국어': 99, '영어': 62, '수학': 55, '과학': 66}], [{'반': '1학년 3반'}, {'학생': '1학년3반1번', '국어': 55, '영어': 74, '수학': 96, '과학': 31}, {'학생': '1학년3반2번', '국어': 68, '영어': 52, '수학': 90, '과학': 71}, {'학생': '1학년3반3번', '국어': 98, '영어': 86, '수학': 84, '과학': 69}, {'학생': '1학년3반4번', '국어': 86, '영어': 86, '수학': 62, '과학': 35}, {'학생': '1학년3반5번', '국어': 37, '영어': 62, '수학': 55, '과학': 76}]]
# B
# [{'학년': '1학년'}, [{'반': '1학년 1반'}, {'학생': '1학년1반1번', '국어': 'D', '영어': 'A', '수학': 'D', '과학': 'D'}, {'학생': '1학년1반2번', '국어': 'D', '영어': 'D', '수학': 'D', '과학': 'C'}, {'학생': '1학년1반3번', '국어': 'A', '영어': 'A', '수학': 'D', '과학': 'D'}, {'학생': '1학년1반4번', '국어': 'D', '영어': 'D', '수학': 'D', '과학': 'C'}, {'학생': '1학년1반5번', '국어': 'D', '영어': 'B', '수학': 'D', '과학': 'D'}, {'학생': '1학년1반6번', '국어': 'D', '영어': 'D', '수학': 'D', '과학': 'D'}, {'학생': '1학년1반7번', '국어': 'A', '영어': 'A', '수학': 'A', '과학': 'D'}], [{'반': '1학년 2반'}, {'학생': '1학년2반1번', '국어': 'D', '영어': 'D', '수학': 'D', '과학': 'D'}, {'학생': '1학년2반2번', '국어': 'D', '영어': 'A', '수학': 'D', '과학': 'B'}, {'학생': '1학년2반3번', '국어': 'D', '영어': 'B', '수학': 'D', '과학': 'D'}, {'학생': '1학년2반4번', '국어': 'A', '영어': 'D', '수학': 'D', '과학': 'D'}], [{'반': '1학년 3반'}, {'학생': '1학년3반1번', '국어': 'D', '영어': 'C', '수학': 'A', '과학': 'D'}, {'학생': '1학년3반2번', '국어': 'D', '영어': 'D', '수학': 'A', '과학': 'C'}, {'학생': '1학년3반3번', '국어': 'A', '영어': 'B', '수학': 'B', '과학': 'D'}, {'학생': '1학년3반4번', '국어': 'B', '영어': 'B', '수학': 'D', '과학': 'D'}, {'학생': '1학년3반5번', '국어': 'D', '영어': 'D', '수학': 'D', '과학': 'C'}]]
# [{'학년': '1학년'}, [{'반': '1학년 1반'}, {'학생': '1학년1반1번', '국어': 'D', '영어': 'A', '수학': 'D', '과학': 'D', '평균': 60.5}, {'학생': '1학년1반2번', '국어': 'D', '영어': 'D', '수학': 'D', '과학': 'C', '평균': 52.0}, {'학생': '1학년1반3번', '국어': 'A', '영어': 'A', '수학': 'D', '과학': 'D', '평균': 76.0}, {'학생': '1학년1반4번', '국어': 'D', '영어': 'D', '수학': 'D', '과학': 'C', '평균': 57.5}, {'학생': '1학년1반5번', '국어': 'D', '영어': 'B', '수학': 'D', '과학': 'D', '평균': 67.5}, {'학생': '1학년1반6번', '국어': 'D', '영어': 'D', '수학': 'D', '과학': 'D', '평균': 53.0}, {'학생': '1학년1반7번', '국어': 'A', '영어': 'A', '수학': 'A', '과학': 'D', '평균': 86.0}], [{'반': '1학년 2반'}, {'학생': '1학년2반1번', '국어': 'D', '영어': 'D', '수학': 'D', '과학': 'D', '평균': 57.25}, {'학생': '1학년2반2번', '국어': 'D', '영어': 'A', '수학': 'D', '과학': 'B', '평균': 77.0}, {'학생': '1학년2반3번', '국어': 'D', '영어': 'B', '수학': 'D', '과학': 'D', '평균': 52.0}, {'학생': '1학년2반4번', '국어': 'A', '영어': 'D', '수학': 'D', '과학': 'D', '평균': 70.5}], [{'반': '1학년 3반'}, {'학생': '1학년3반1번', '국어': 'D', '영어': 'C', '수학': 'A', '과학': 'D', '평균': 64.0}, {'학생': '1학년3반2번', '국어': 'D', '영어': 'D', '수학': 'A', '과학': 'C', '평균': 70.25}, {'학생': '1학년3반3번', '국어': 'A', '영어': 'B', '수학': 'B', '과학': 'D', '평균': 84.25}, {'학생': '1학년3반4번', '국어': 'B', '영어': 'B', '수학': 'D', '과학': 'D', '평균': 67.25}, {'학생': '1학년3반5번', '국어': 'D', '영어': 'D', '수학': 'D', '과학': 'C', '평균': 57.5}]]
# [{'학년': '1학년'}, [{'반': '1학년 1반', '반평균': 64.64285714285714}, {'학생': '1학년1반1번', '국어': 'D', '영어': 'A', '수학': 'D', '과학': 'D', '평균': 60.5}, {'학생': '1학년1반2번', '국어': 'D', '영어': 'D', '수학': 'D', '과학': 'C', '평균': 52.0}, {'학생': '1학년1반3번', '국어': 'A', '영어': 'A', '수학': 'D', '과학': 'D', '평균': 76.0}, {'학생': '1학년1반4번', '국어': 'D', '영어': 'D', '수학': 'D', '과학': 'C', '평균': 57.5}, {'학생': '1학년1반5번', '국어': 'D', '영어': 'B', '수학': 'D', '과학': 'D', '평균': 67.5}, {'학생': '1학년1반6번', '국어': 'D', '영어': 'D', '수학': 'D', '과학': 'D', '평균': 53.0}, {'학생': '1학년1반7번', '국어': 'A', '영어': 'A', '수학': 'A', '과학': 'D', '평균': 86.0}], [{'반': '1학년 2반'}, {'학생': '1학년2반1번', '국어': 'D', '영어': 'D', '수학': 'D', '과학': 'D', '평균': 57.25}, {'학생': '1학년2반2번', '국어': 'D', '영어': 'A', '수학': 'D', '과학': 'B', '평균': 77.0}, {'학생': '1학년2반3번', '국어': 'D', '영어': 'B', '수학': 'D', '과학': 'D', '평균': 52.0}, {'학생': '1학년2반4번', '국어': 'A', '영어': 'D', '수학': 'D', '과학': 'D', '평균': 70.5}], [{'반': '1학년 3반'}, {'학생': '1학년3반1번', '국어': 'D', '영어': 'C', '수학': 'A', '과학': 'D', '평균': 64.0}, {'학생': '1학년3반2번', '국어': 'D', '영어': 'D', '수학': 'A', '과학': 'C', '평균': 70.25}, {'학생': '1학년3반3번', '국어': 'A', '영어': 'B', '수학': 'B', '과학': 'D', '평균': 84.25}, {'학생': '1학년3반4번', '국어': 'B', '영어': 'B', '수학': 'D', '과학': 'D', '평균': 67.25}, {'학생': '1학년3반5번', '국어': 'D', '영어': 'D', '수학': 'D', '과학': 'C', '평균': 57.5}]]
# [{'학년': '1학년', '학년평균': 65.82678571428572}, [{'반': '1학년 1반', '반평균': 64.64285714285714}, {'학생': '1학년1반1번', '국어': 'D', '영어': 'A', '수학': 'D', '과학': 'D', '평균': 60.5}, {'학생': '1학년1반2번', '국어': 'D', '영어': 'D', '수학': 'D', '과학': 'C', '평균': 52.0}, {'학생': '1학년1반3번', '국어': 'A', '영어': 'A', '수학': 'D', '과학': 'D', '평균': 76.0}, {'학생': '1학년1반4번', '국어': 'D', '영어': 'D', '수학': 'D', '과학': 'C', '평균': 57.5}, {'학생': '1학년1반5번', '국어': 'D', '영어': 'B', '수학': 'D', '과학': 'D', '평균': 67.5}, {'학생': '1학년1반6번', '국어': 'D', '영어': 'D', '수학': 'D', '과학': 'D', '평균': 53.0}, {'학생': '1학년1반7번', '국어': 'A', '영어': 'A', '수학': 'A', '과학': 'D', '평균': 86.0}], [{'반': '1학년 2반', '반평균': 64.1875}, {'학생': '1학년2반1번', '국어': 'D', '영어': 'D', '수학': 'D', '과학': 'D', '평균': 57.25}, {'학생': '1학년2반2번', '국어': 'D', '영어': 'A', '수학': 'D', '과학': 'B', '평균': 77.0}, {'학생': '1학년2반3번', '국어': 'D', '영어': 'B', '수학': 'D', '과학': 'D', '평균': 52.0}, {'학생': '1학년2반4번', '국어': 'A', '영어': 'D', '수학': 'D', '과학': 'D', '평균': 70.5}], [{'반': '1학년 3반', '반평균': 68.65}, {'학생': '1학년3반1번', '국어': 'D', '영어': 'C', '수학': 'A', '과학': 'D', '평균': 64.0}, {'학생': '1학년3반2번', '국어': 'D', '영어': 'D', '수학': 'A', '과학': 'C', '평균': 70.25}, {'학생': '1학년3반3번', '국어': 'A', '영어': 'B', '수학': 'B', '과학': 'D', '평균': 84.25}, {'학생': '1학년3반4번', '국어': 'B', '영어': 'B', '수학': 'D', '과학': 'D', '평균': 67.25}, {'학생': '1학년3반5번', '국어': 'D', '영어': 'D', '수학': 'D', '과학': 'C', '평균': 57.5}]]
# [{'학년': '1학년', '학년평균': 65.82678571428572}, [{'반': '1학년 1반', '반평균': 64.64285714285714, '반분산': 136.69387755102042, '반표준편차': 11.691615694634358}, {'학생': '1학년1반1번', '국어': 'D', '영어': 'A', '수학': 'D', '과학': 'D', '평균': 60.5}, {'학생': '1학년1반2번', '국어': 'D', '영어': 'D', '수학': 'D', '과학': 'C', '평균': 52.0}, {'학생': '1학년1반3번', '국어': 'A', '영어': 'A', '수학': 'D', '과학': 'D', '평균': 76.0}, {'학생': '1학년1반4번', '국어': 'D', '영어': 'D', '수학': 'D', '과학': 'C', '평균': 57.5}, {'학생': '1학년1반5번', '국어': 'D', '영어': 'B', '수학': 'D', '과학': 'D', '평균': 67.5}, {'학생': '1학년1반6번', '국어': 'D', '영어': 'D', '수학': 'D', '과학': 'D', '평균': 53.0}, {'학생': '1학년1반7번', '국어': 'A', '영어': 'A', '수학': 'A', '과학': 'D', '평균': 86.0}], [{'반': '1학년 2반', '반평균': 64.1875}, {'학생': '1학년2반1번', '국어': 'D', '영어': 'D', '수학': 'D', '과학': 'D', '평균': 57.25}, {'학생': '1학년2반2번', '국어': 'D', '영어': 'A', '수학': 'D', '과학': 'B', '평균': 77.0}, {'학생': '1학년2반3번', '국어': 'D', '영어': 'B', '수학': 'D', '과학': 'D', '평균': 52.0}, {'학생': '1학년2반4번', '국어': 'A', '영어': 'D', '수학': 'D', '과학': 'D', '평균': 70.5}], [{'반': '1학년 3반', '반평균': 68.65}, {'학생': '1학년3반1번', '국어': 'D', '영어': 'C', '수학': 'A', '과학': 'D', '평균': 64.0}, {'학생': '1학년3반2번', '국어': 'D', '영어': 'D', '수학': 'A', '과학': 'C', '평균': 70.25}, {'학생': '1학년3반3번', '국어': 'A', '영어': 'B', '수학': 'B', '과학': 'D', '평균': 84.25}, {'학생': '1학년3반4번', '국어': 'B', '영어': 'B', '수학': 'D', '과학': 'D', '평균': 67.25}, {'학생': '1학년3반5번', '국어': 'D', '영어': 'D', '수학': 'D', '과학': 'C', '평균': 57.5}]]
# [{'학년': '1학년', '학년평균': 65.82678571428572, '학년분산': 113.2354719387755, '학년표준편차': 10.641215717143202}, [{'반': '1학년 1반', '반평균': 64.64285714285714, '반분산': 136.69387755102042, '반표준편차': 11.691615694634358}, {'학생': '1학년1반1번', '국어': 'D', '영어': 'A', '수학': 'D', '과학': 'D', '평균': 60.5}, {'학생': '1학년1반2번', '국어': 'D', '영어': 'D', '수학': 'D', '과학': 'C', '평균': 52.0}, {'학생': '1학년1반3번', '국어': 'A', '영어': 'A', '수학': 'D', '과학': 'D', '평균': 76.0}, {'학생': '1학년1반4번', '국어': 'D', '영어': 'D', '수학': 'D', '과학': 'C', '평균': 57.5}, {'학생': '1학년1반5번', '국어': 'D', '영어': 'B', '수학': 'D', '과학': 'D', '평균': 67.5}, {'학생': '1학년1반6번', '국어': 'D', '영어': 'D', '수학': 'D', '과학': 'D', '평균': 53.0}, {'학생': '1학년1반7번', '국어': 'A', '영어': 'A', '수학': 'A', '과학': 'D', '평균': 86.0}], [{'반': '1학년 2반', '반평균': 64.1875}, {'학생': '1학년2반1번', '국어': 'D', '영어': 'D', '수학': 'D', '과학': 'D', '평균': 57.25}, {'학생': '1학년2반2번', '국어': 'D', '영어': 'A', '수학': 'D', '과학': 'B', '평균': 77.0}, {'학생': '1학년2반3번', '국어': 'D', '영어': 'B', '수학': 'D', '과학': 'D', '평균': 52.0}, {'학생': '1학년2반4번', '국어': 'A', '영어': 'D', '수학': 'D', '과학': 'D', '평균': 70.5}], [{'반': '1학년 3반', '반평균': 68.65}, {'학생': '1학년3반1번', '국어': 'D', '영어': 'C', '수학': 'A', '과학': 'D', '평균': 64.0}, {'학생': '1학년3반2번', '국어': 'D', '영어': 'D', '수학': 'A', '과학': 'C', '평균': 70.25}, {'학생': '1학년3반3번', '국어': 'A', '영어': 'B', '수학': 'B', '과학': 'D', '평균': 84.25}, {'학생': '1학년3반4번', '국어': 'B', '영어': 'B', '수학': 'D', '과학': 'D', '평균': 67.25}, {'학생': '1학년3반5번', '국어': 'D', '영어': 'D', '수학': 'D', '과학': 
5: 1}, '평균_반빈도': {67.5: 0.2857142857142857, 76.0: 0.2857142857142857, 52.0: 0.2857142857142857, 53.0: 0.2857142857142857, 86.0: 0.2857142857142857, 57.5: 0.2857142857142857, 60.5: 0.2857142857142857}}, {'학생': '1학년1반1번', '국어': 'D', '영어': 'A', '수학': 'D', '과학': 'D', '평균': 60.5}, {'학생': '1학년1반2번', '국어': 'D', '영어': 'D', '수학': 'D', '과학': 'C', '평균': 52.0}, {'학생': '1학년1반3번', '국어': 'A', '영어': 'A', '수학': 'D', '과학': 'D', '평균': 76.0}, {'학생': '1학년1반4번', '국어': 'D', '영어': 'D', '수학': 'D', '과학': 'C', '평균': 57.5}, {'학생': '1학년1반5번', '국어': 'D', '영어': 'B', '수학': 'D', '과학': 'D', '평균': 67.5}, {'학생': '1학년1반6번', '국어': 'D', '영어': 'D', '수학': 'D', '과학': 'D', '평균': 53.0}, {'학생': '1학년1반7번', '국어': 'A', '영어': 'A', '수학': 'A', '과학': 'D', '평균': 86.0}], [{'반': '1학년 2반', '반평균': 64.1875, '국어_반누적분포': {32: 1, 99: 1, 59: 1, 47: 1}, '국어_반빈도': {32: 0.5, 99: 0.5, 59: 0.5, 47: 0.5}, '영어_반누적분포': {62: 1, 82: 1, 94: 1, 63: 1}, '영어_반빈도': {62: 0.5, 82: 0.5, 94: 0.5, 63: 0.5}, '수학_반누적분포': {64: 1, 48: 1, 67: 1, 55: 1}, '수학_반빈도': {64: 0.5, 48: 0.5, 67: 0.5, 55: 0.5}, '과학_반누적분포': {88: 1, 66: 1, 46: 1, 55: 1}, '과학_반빈도': {88: 0.5, 66: 0.5, 46: 0.5, 55: 0.5}, '평균_반누적분포': {57.25: 1, 52.0: 1, 77.0: 1, 70.5: 1}, '평균_반빈도': {57.25: 0.5, 52.0: 0.5, 77.0: 0.5, 70.5: 0.5}}, {'학생': '1학년2반1번', '국어': 'D', '영어': 'D', '수학': 'D', '과학': 'D', '평균': 57.25}, {'학생': '1학년2반2번', '국어': 'D', '영어': 'A', '수 ...

# %%
grade6=score_analysis()
grade6.csv열기("6학년") #문제점 발견, 학생의 자료를 저장하고 불러올때 [str,{}]꼴이 유지된게 아니라 통째 str로 인식
#제대로된 자료형에서 되던게 여기선 안됨, 파일을 열어서 리스트에 저장할때 이를 보정할 새로운 알고리즘 필요//해결
#['6학년1반1번', {'국어': 42, '영어': 34, '수학': 53, '과학': 87}]모양의 string을 원래대로 돌려야함//해결
print(grade6.grade[1][1])
grade6.results=grade6.grade
grade6.등급부여()
print(grade6.results)
# Out:
# ['6학년', ['6학년 1반', ['6학년1반1번', {'국어': 64, '영어': 97, '수학': 31, '과학': 98}], ['6학년1반2번', {'국어': 94, '영어': 100, '수학': 55, '과학': 34}], ['6학년1반3번', {'국어': 89, '영어': 39, '수학': 72, '과학': 32}], ['6학년1반4번', {'국어': 59, '영어': 33, '수학': 64, '과학': 33}], ['6학년1반5번', {'국어': 76, '영어': 94, '수학': 66, '과학': 37}]], ['6학년 2반', ['6학년2반1번', {'국어': 52, '영어': 78, '수학': 63, '과학': 79}], ['6학년2반2번', {'국어': 92, '영어': 58, '수학': 45, '과학': 40}], ['6학년2반3번', {'국어': 80, '영어': 80, '수학': 93,
}], ['6학년8반2번', {'국어': 39, '영어': 48, '수학': 88, '과학': 43}], ['6학년8반3번', {'국어': 37, '영어': 98, '수학': 87, '과학': 36}], ['6학년8반4번', {'국어': 85, '영어': 96, '수학': 77, '과학': 80}], ['6학년8반5번', {'국어': 32, '영어': 71, '수학': 93, '과학': 98}], ['6학년8반6번', {'국어': 30, '영어': 31, '수학': 96, '과학': 79}]]]
# 6학년.csv파일을 여는데 성공했습니다.
# ['6학년1반1번', {'국어': 64, '영어': 97, '수학': 31, '과학': 98}]
# ['6학년', ['6학년 1반', ['6학년1반1번', {'국어': 'D', '영어': 'A', '수학': 'D', '과학': 'A'}], ['6학년1반2번', {'국어': 'A', '영어': 'A', '수학': 'D', '과학': 'D'}], ['6학년1반3번', {'국어': 'B', '영어': 'D', '수학': 'C', '과학': 'D'}], ['6학년1반4번', {'국어': 'D', '영어': 'D', '수학': 'D', '과학': 'D'}], ['6학년1반5번', {'국어': 'C', '영어': 'A', '수학': 'D', '과학': 'D'}]], ['6학년 2반', ['6학년2반1번', {'국어': 'D', '영어': 'C', '수학': 'D', '과학': 'C'}], ['6학년2반2번', {'국어': 'A', '영어': 'D', '수학': 'D', '과학': 'D'}], ['6학년2반3번', {'국어': 'B', '영어': 'B', '수학': 'A', '과학': 'D'}], ['6학년2반4번', {'국어': 'A', '영어': 'D', '수학': 'D', '과학': 'D'}]], ['6학년 3반', ['6학년3반1번', {'국어': 'B', '영어': 'A', '수학': 'C', '과학': 'C'}], ['6학년3반2번', {'국어': 'D', '영어': 'A', '수학': 'C', '과학': 'A'}], ['6학년3반3번', {'국어': 'B', '영어': 'D', '수학': 'C', '과학': 'D'}], ['6학년3반4번', {'국어': 'D', '영어': 'D', '수학': 'D', '과학': 'D'}], ['6학년3반5번', {'국어': 'B', '영어': 'D', '수학': 'A', '과학': 'D'}]], ['6학년 4반', ['6학년4반1번', {'국어': 'C', '영어': 'C', '수학': 'D', '과학': 'C'}], ['6학년4반2번', {'국어': 'D', '영어': 'D', '수학': 'A', '과학': 'D'}], ['6학년4반3번', {'국어': 'D', '영어': 'D', '수학': 'B', '과학': 'D'}], ['6학년4반4번', {'국어': 'B', '영어': 'D', '수학': 'A', '과학': 'C'}], ['6학년4반5번', {'국어': 'D', '영어': 'D', '수학': 'D', '과학': 'A'}], ['6학년4반6번', {'국어': 'C', '영어': 'D', '수학': 'D', '과학': 'D'}], ['6학년4반7번', {'국어': 'D', '영어': 'C', '수학': 'D', '과학': 'D'}], ['6학년4반8번', {'국어': 'C', '영어': 'B', '수학': 'A', '과학': 'D'}]], ['6학년 5반', ['6학년5반1번', {'국어': 'D', '영어': 'A', '수학': 'D', '과학': 'D'}], ['6학년5반2번', {'국어': 'D', '영어': 'D', '수학': 'D', '과학': 'D'}], ['6학년5반3번', {'국어': 'D', '영어': 'A', '수학': 'B', '과학': 'A'}], ['6학년5반4번', {'국어': 'D', '영어': 'B', '수학': 'C', '과학': 'A'}], ['6학년5반5번', {'국어': 'D', '영어': 'D', '수학': 'C', '과학': 'C'}], ['6학년5반6번', {'국어': 'D', '영어': 'D', '수학': 'D', '과학': 'D'}], ['6학년5반7번', {'국어': 'D', '영어': 'D', '수학': 'A', '과학': 'D'}], ['6학년5반8번', {'국어': 'B', '영어': 'D', '수학': 'D', '과학': 'B'}]], ['6학년 6반', ['6학년6반1번', {'국어': 'D', '영어': 'A', '수학': 'C', '과학': 'D'}], ['6학년6반2번', {'국어': 'C', '영어': 'D', '수학': 'D', '과학': 'D'}], ['6학년6반3번', {'국어': 'D', '영어': 'D', '수학': 'D', '과학': 'A'}], ['6학년6반4번', {'국어': 'C', '영어': 'D', '수학': 'A', '과학': 'C'}], ['6학년6반5번', {'국어': 'B', '영어': 'A', '수학': 'D', '과학': 'B'}]], ['6학년 7반', ['6학년7반1번', {'국어': 'D', '영어': 'A', '수학': 'D', '과학': 'A'}], ['6학년7반2번', {'국어': 'D', '영어': 'A', '수학': 'B', '과학': 'D'}], ['6학년7반3번', {'국어': 'D', '영어': 'B', '수학': 'D', '과학': 'A'}], ['6학년7반4번', {'국어': 'D', '영어': 'D', '수학': 'D', '과학': 'D'}], ['6학년7반5번', {'국어': 'D', '영어': 'D', '수학': 'D', '과학': 'D'}], ['6학년7반6번', {'국어': 'D', '영어': 'D', '수학': 'A', '과학': 'D'}], ['6학년7반7번', {'국어': 'D', '영어': 'D', '수학': 'B', '과학': 'D'}], ['6학년7반8번', {'국어': 'A', '영어': 'D', '수학': 'D', '과학': 'D'}], ['6학년7반9번', {'국어': 'A', '영어': 'D', '수학': 'D', '과학': 'D'}]], ['6학년 8반', ['6학년8반1번', {'국어': 'D', '영어': 'D', '수학': 'D', '과학': 'C'}], ['6학년8반2번', {'국어': 'D', '영어': 'D', '수학': 'B', '과학': 'D'}], ['6학년8반3번', {'국어': 'D', '영어': 'A', '수학': 'B', '과학': 'D'}], ['6학년8반4번', {'국어': 'B', '영어': 'A', '수학': 'C', '과학': 'B'}], ['6학년8반5번', {'국어': 'D', '영어': 'C', '수학': 'A', '과학': 'A'}], ['6학년8반6번', {'국어': 'D', '영어': 'D', '수학': 'A', '과학': 'C'}]]]

# %%
#['6학년1반1번', {'국어': 42, '영어': 34, '수학': 53, '과학': 87}]모양의 string을 원래대로 리스트와 딕셔너리로 변환하는 새로운 함수 필요//해결
  
AA="['6학년1반1번', {'국어': 42, '영어': 34, '수학': 53, '과학': 87}]"
BB=AA.split(',')
print(BB)
for i in range(len(BB)):
  BB[i]=BB[i].replace("[","").replace("]","").replace("{","").replace("}","").replace("'","").replace(" ","") #연속작업을 이렇게도 처리 가능
print(BB)
L=[]
D={}
for X in BB:
  if ':' in X:
    T=X.split(':')
    print(T)
    D[T[0]]=int(T[1])
L=[BB[0],D]
print(L)
# Out:
# ["['6학년1반1번'", " {'국어': 42", " '영어': 34", " '수학': 53", " '과학': 87}]"]
# ['6학년1반1번', '국어:42', '영어:34', '수학:53', '과학:87']
# ['국어', '42']
# ['영어', '34']
# ['수학', '53']
# ['과학', '87']
# ['6학년1반1번', {'국어': 42, '영어': 34, '수학': 53, '과학': 87}]
