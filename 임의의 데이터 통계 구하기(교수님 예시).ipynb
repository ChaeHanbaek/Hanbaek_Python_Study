# %%
import random
import csv
import pandas as pd
import matplotlib.pyplot as plt

# %%
default_rand_nums = 10
default_min_of_rand_num = 0
default_max_of_rand_num = 10

str_inform = """이 프로그램은 임의의 숫자를 생성하고 그결과를 csv 파일로 저장, 통계 분석하는 기능을 제공합니다.\
\n숫자를 생성하기 위하여, 생성할 숫자의 갯수(n), 임의의 숫자 생성을 위한 범위의 최솟값(min),최댓값(max)를 설정할 수 있습니다.\
\n이 옵션의 기본값은  n= {n}, min={min}, max = {max}입니다.\
\n 기본값으로 숫자를 생성하고자 하실 경우에는 'd'를 입력하고, 숫자 생성을 종료하실 경우에는 'q'를 입력하시면 됩니다.\n""".format(n=default_rand_nums, min=default_min_of_rand_num, max=default_max_of_rand_num)

str_rand_num="생성할 숫자의 옵션 n,min,max를 스페이스바로 구분하여 입력해주세요.('q','d'입력 가능) : "

# %%
def rand_num_gen(_nums = default_rand_nums, _min=default_min_of_rand_num, _max=default_max_of_rand_num):
  res = []
  for i in range(_nums):
    num = random.randint(_min, _max)
    res.append(num)
    return res
